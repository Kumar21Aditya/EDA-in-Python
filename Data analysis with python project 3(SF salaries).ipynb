# %%
import pandas as pd

# %%
df1=pd.read_csv('C:/Users/adity/Downloads/Salaries.csv')
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_5764\13169804.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1=pd.read_csv('C:/Users/adity/Downloads/Salaries.csv')

# %%
df1
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %% [markdown]
# # Display top 15 rows

# %%
df1.head(15)
# Out:
#     Id        EmployeeName                                          JobTitle  \
# 0    1      NATHANIEL FORD    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1    2        GARY JIMENEZ                   CAPTAIN III (POLICE DEPARTMENT)
# 2    3      ALBERT PARDINI                   CAPTAIN III (POLICE DEPARTMENT)
# 3    4   CHRISTOPHER CHONG              WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    5     PATRICK GARDNER      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5    6      DAVID SULLIVAN                         ASSISTANT DEPUTY CHIEF II
# 6    7           ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)
# 7    8       DAVID KUSHNER                    DEPUTY DIRECTOR OF INVESTMENTS
# 8    9      MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 9   10  JOANNE HAYES-WHITE            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 10  11       ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# ...

# %% [markdown]
# # Display last 8 rows

# %%
df1.tail(8)
# Out:
#             Id    EmployeeName                     JobTitle       BasePay  \
# 148646  148647    Not provided                 Not provided  Not Provided
# 148647  148648  Joann Anderson  Communications Dispatcher 2             0
# 148648  148649     Leon Walker                    Custodian             0
# 148649  148650   Roy I Tillery                    Custodian             0
# 148650  148651    Not provided                 Not provided  Not Provided
# 148651  148652    Not provided                 Not provided  Not Provided
# 148652  148653    Not provided                 Not provided  Not Provided
# 148653  148654       Joe Lopez   Counselor, Log Cabin Ranch             0
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# 148646  Not Provided  Not Provided  Not Provided      0.00              0.00
# 148647             0             0             0      0.00              0.00
# ...

# %% [markdown]
# # Find the shape of your dataset(row and column wise)

# %%
print(df1.shape)
print("total no of rows=",df1.shape[0])
print("total no of columns=",df1.shape[1])
# Out:
# (148654, 13)
# total no of rows= 148654
# total no of columns= 13

# %% [markdown]
# # Getting information about dataset like total no of rows,totakl no of columns ,datatypes of each column and memory requirement

# %%
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB
# None

# %% [markdown]
# # Check null values in the Dataset

# %%
df1.isnull()
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0       False         False     False    False        False     False
# 1       False         False     False    False        False     False
# 2       False         False     False    False        False     False
# 3       False         False     False    False        False     False
# 4       False         False     False    False        False     False
# ...       ...           ...       ...      ...          ...       ...
# 148649  False         False     False    False        False     False
# 148650  False         False     False    False        False     False
# 148651  False         False     False    False        False     False
# 148652  False         False     False    False        False     False
# 148653  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# ...

# %%
df1.isnull().sum(axis=0)#column wise
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
df1.isnull().sum(axis=1)#row wise
# Out:
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
#          ..
# 148649    1
# 148650    2
# 148651    2
# 148652    2
# 148653    1
# Length: 148654, dtype: int64

# %% [markdown]
# # Drop ID,Notes,Agency and Status Columns

# %%
df1=df1.drop(['Id','Notes','Agency','Status'],axis=1)

# %%
df1.head(1)
# Out:
#      EmployeeName                                        JobTitle    BasePay  \
# 0  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
#
#   OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  Year
# 0         0.0  400184.25      NaN  567595.43         567595.43  2011

# %% [markdown]
# # Get overall statistics about the dataset

# %%
df1.describe(include='all')
# Out:
#        EmployeeName          JobTitle   BasePay  OvertimePay  OtherPay  \
# count        148654            148654  148049.0     148654.0  148654.0
# unique       110811              2159  109900.0      66555.0   84968.0
# top       Kevin Lee  Transit Operator       0.0          0.0       0.0
# freq             13              7036     875.0      66103.0   35218.0
# mean            NaN               NaN       NaN          NaN       NaN
# std             NaN               NaN       NaN          NaN       NaN
# min             NaN               NaN       NaN          NaN       NaN
# 25%             NaN               NaN       NaN          NaN       NaN
# 50%             NaN               NaN       NaN          NaN       NaN
# 75%             NaN               NaN       NaN          NaN       NaN
# max             NaN               NaN       NaN          NaN       NaN
#
#         Benefits       TotalPay  TotalPayBenefits           Year
# ...

# %% [markdown]
# # Find the occurance of the employee name(top 5)

# %%
df1['EmployeeName'].value_counts().head()
# Out:
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: EmployeeName, dtype: int64

# %% [markdown]
# # Find the number of unique job titels

# %%
df1.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
df1['JobTitle'].nunique()#2159 no of job titels are unique
# Out:
# 2159

# %% [markdown]
# # total number of job titels containing captian

# %%
len(df1[df1['JobTitle'].str.contains('Captain',case=False)])
# Out:
# 552

# %%
df1[df1['JobTitle'].str.contains('Captain',case=False)].count()
# Out:
# EmployeeName        552
# JobTitle            552
# BasePay             551
# OvertimePay         552
# OtherPay            552
# Benefits            411
# TotalPay            552
# TotalPayBenefits    552
# Year                552
# dtype: int64

# %% [markdown]
# # All the employee name from the fire department only

# %%
df1[df1['JobTitle'].str.contains('fire',case=False)]['EmployeeName']
# Out:
# 4            PATRICK GARDNER
# 6                  ALSON LEE
# 8             MICHAEL MORRIS
# 9         JOANNE HAYES-WHITE
# 10             ARTHUR KENNEY
#                  ...
# 145956      Kenneth C Farris
# 147556         Edward A Dunn
# 148021        Kari A Johnson
# 148209          Sheryl K Lee
# 148554       Lawrence F Gatt
# Name: EmployeeName, Length: 5879, dtype: object

# %% [markdown]
# # Find the minimum,maximum and average TotalPay

# %%
print(df1['TotalPay'].describe())
print(df1['TotalPay'].max())
print(df1['TotalPay'].min())
print(df1['TotalPay'].mean())
# Out:
# count    148654.000000
# mean      74768.321972
# std       50517.005274
# min        -618.130000
# 25%       36168.995000
# 50%       71426.610000
# 75%      105839.135000
# max      567595.430000
# Name: TotalPay, dtype: float64
# 567595.43
# -618.13
# 74768.321971703

# %% [markdown]
# # Replace "Not Provided" in EmployeeName column to NaN

# %%
import numpy as np
df1['EmployeeName']=df1['EmployeeName'].replace('Not provided',np.nan)
df1
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650                NaN                                    Not provided
# 148651                NaN                                    Not provided
# 148652                NaN                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...

# %% [markdown]
# # drop the rows having 1 missing values

# %%
df1.drop(df1[df1.isnull().sum(axis=1)==1].index,axis=0,inplace=True)#inplace is used for permanent change

# %%
df1
# Out:
#               EmployeeName                      JobTitle    BasePay  \
# 36159       Gary Altenberg  Lieutenant, Fire Suppression  128808.87
# 36160         Gregory Suhr               Chief of Police   302578.0
# 36161           Khoa Trinh   Electronic Maintenance Tech   111921.0
# 36162   Joanne Hayes-White        Chief, Fire Department  296943.01
# 36163    Frederick Binkley     EMT/Paramedic/Firefighter  126863.19
# ...                    ...                           ...        ...
# 148645    Carolyn A Wilson     Human Services Technician          0
# 148647      Joann Anderson   Communications Dispatcher 2          0
# 148648         Leon Walker                     Custodian          0
# 148649       Roy I Tillery                     Custodian          0
# 148653           Joe Lopez    Counselor, Log Cabin Ranch          0
#
#        OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# 36159    220909.48  13126.31  44430.12  362844.66         407274.78  2012
# ...

# %% [markdown]
# # Find job titel of Gregory Suhr

# %%
df1[df1['EmployeeName']=='Gregory Suhr']['JobTitle']
# Out:
# 36160    Chief of Police
# Name: JobTitle, dtype: object

# %% [markdown]
# # How much Gregory Suhr make(include benifits)

# %%
df1[df1['EmployeeName']=='Gregory Suhr']['TotalPayBenefits']
# Out:
# 36160    391362.3
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# # display the name of the person having highest TotalPayBenefits

# %%
df1[df1['TotalPayBenefits'].max()==df1['TotalPayBenefits']]['EmployeeName']
# Out:
# 110531    David Shinn
# Name: EmployeeName, dtype: object

# %% [markdown]
# # find the average TotalPayBenefits of all employee per year

# %%
df1.groupby('Year').mean()['TotalPayBenefits']
# Out:
# Year
# 2012    100553.229232
# 2013    102939.981346
# 2014    100261.438668
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# # find the average TotalPayBenefits of all employee per JobTitle

# %%
df1.groupby('JobTitle').mean()['TotalPayBenefits']
# Out:
# JobTitle
# ACPO,JuvP, Juv Prob (SFERS)        80266.370000
# ASR Senior Office Specialist       90124.237333
# ASR-Office Assistant               60762.093659
# Account Clerk                      63246.342000
# Accountant I                       88122.188750
#                                       ...
# Wire Rope Cable Maint Sprv        242118.323333
# Worker's Comp Supervisor 1         96125.531429
# Worker's Compensation Adjuster    101321.425811
# X-Ray Laboratory Aide              69521.123200
# Youth Comm Advisor                 60118.550000
# Name: TotalPayBenefits, Length: 1109, dtype: float64

# %% [markdown]
# # # find the average TotalPayBenefits of all employee per JobTitle Custodian

# %%
df1[df1['JobTitle']=='Custodian']['TotalPayBenefits'].mean()
# Out:
# 68411.81545039438

# %% [markdown]
# # find top 5 most common jobs

# %%
df1['JobTitle'].value_counts().head()
# Out:
# Transit Operator                6975
# Special Nurse                   4382
# Registered Nurse                3725
# Public Svc Aide-Public Works    2514
# Police Officer 3                2411
# Name: JobTitle, dtype: int64
